# %% [markdown]
# <a href="https://colab.research.google.com/github/MrLuksR/ClasificacionDeOpiniones-PLN/blob/main/Clasificaci%C3%B3n_de_Opiniones_PLN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importación del archivo train

# %%
import pandas as pd
df = pd.read_csv('dataset_train_95.csv')
df.head()
# Out:
#        id           autor                                        declaracion  \
# 0  116196  Ciara O'Rourke             CDC just cancelled Halloween for kids.
# 1  118599  Ciara O'Rourke  Coroner saying George Floyd died of drug overd...
# 2  133975   Tom Kertscher  Says Nancy Pelosi made millions in coronavirus...
# 3   92314   Caryn Shinske  New Jersey has "the highest property taxes in ...
# 4   72507  Louis Jacobson  "Nearly 6 out of 10 believe that money and wea...
#
#    etiqueta                          palabras_clave  \
# 0         0               CDC, cancelled, Halloween
# 1         0       George Floyd, died, drug overdose
# 2         0  pelosi, made millions, insider trading
# 3         1      New Jersey, highest property taxes
# 4         1          money, more evenly distributed
#
#                                                tweet  \
# 0  If the CDC wants people to not crowd and party...
# 1  @GlennLoury George Floyd died of a drug overdo...
# ...

# %% [markdown]
# # Comprobando datos null

# %%
df.isnull().sum()
# Out:
# id                               0
# autor                            0
# declaracion                      0
# etiqueta                         0
# palabras_clave                   0
# tweet                            0
# respuesta_mayoria_5_etiquetas    0
# respuesta_mayoria_3_etiquetas    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['declaracion'] + ' ' + df['palabras_clave'] + ' ' + df['tweet'] + ' ' + df['respuesta_mayoria_5_etiquetas'] + ' ' + df['respuesta_mayoria_3_etiquetas'], df['etiqueta'], test_size=0.10)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizador = CountVectorizer()
X_train_vec = vectorizador.fit_transform(X_train)
X_test_vec = vectorizador.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression()
modelo.fit(X_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
df_test = pd.read_csv('dataset_test_5_sin_etiqueta.csv')

# %%
df_test.info()
df_test.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4295 entries, 0 to 4294
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             4295 non-null   int64
#  1   autor                          4295 non-null   object
#  2   declaracion                    4295 non-null   object
#  3   palabras_clave                 4295 non-null   object
#  4   tweet                          4295 non-null   object
#  5   respuesta_mayoria_5_etiquetas  4295 non-null   object
#  6   respuesta_mayoria_3_etiquetas  4295 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 235.0+ KB
# id                               0
# autor                            0
# declaracion                      0
# palabras_clave                   0
# tweet                            0
# respuesta_mayoria_5_etiquetas    0
# respuesta_mayoria_3_etiquetas    0
# dtype: int64

# %%
nueva = df_test['declaracion'] + ' ' + df_test['palabras_clave'] + ' ' + df_test['tweet'] + ' ' + df_test['respuesta_mayoria_5_etiquetas'] + ' ' + df_test['respuesta_mayoria_3_etiquetas']
X_nueva = vectorizador.transform(nueva)
predict = modelo.predict(X_nueva)

df_test['etiqueta'] = predict

output = pd.DataFrame({'ID': df_test['id'], 'etiqueta': predict})
output.to_csv('submission3.csv', index=False)
